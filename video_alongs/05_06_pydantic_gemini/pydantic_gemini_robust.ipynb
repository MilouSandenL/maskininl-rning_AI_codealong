# %%
from google import genai
import pydantic

client = genai.Client()

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = " List a few asian soups recipes, a yummy description and list the ingredients"
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Here are a few popular Asian soup recipes, each with a mouth-watering description and its key ingredients!
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **Yummy Description:** Imagine a bowl of pure, aromatic bliss. Pho Bo is a soulful Vietnamese beef noodle soup renowned for its deeply fragrant, slow-simmered broth infused with star anise, cinnamon, and ginger. It cradles tender slices of beef, slippery rice noodles, and a vibrant medley of fresh herbs like basil, mint, and cilantro. Each spoonful is a comforting embrace, a harmonious balance of savory, sweet, and herbaceous notes that will transport you straight to the bustling streets of Hanoi.
#
# **Key Ingredients:**
#
# *   **For the Broth:** Beef bones (marrow and knuckle), flank steak, onions, ginger, star anise, cinnamon sticks, black cardamom pods, cloves, coriander seeds, fish sauce, sugar, salt.
# *   **Noodles:** Flat rice noodles (Bánh Phở).
# *   **Protein:** Thinly sliced raw beef (brisket, round, or eye of round), cooked beef (flank steak, beef balls - optional).
# *   **Garnishes:** Bean sprouts, fresh basil leaves, mint leaves, cilantro, lime wedges, sliced jalapeños or bird's eye chilies, hoisin sauce, Sriracha.
#
# ---
#
# ### 2. Thai Tom Yum Goong (Spicy Shrimp Soup)
#
# **Yummy Description:** Get ready for an explosion of flavors with Tom Yum Goong! This iconic Thai hot and sour soup is a vibrant, zesty masterpiece that awakens every taste bud. It's a fiery dance of spicy chilies, tangy lime, savory fish sauce, and the unmistakable aromatic trio of lemongrass, galangal, and kaffir lime leaves. Succulent shrimp and tender mushrooms swim in a beautifully clear or creamy (with coconut milk or chili paste) broth, creating an exhilarating and utterly addictive experience that's both refreshing and deeply satisfying.
#
# **Key Ingredients:**
#
# *   **Broth Base:** Chicken or vegetable broth.
# *   **Protein:** Fresh shrimp (Goong).
# *   **Aromatics:** Lemongrass (sliced), galangal (sliced), kaffir lime leaves, Thai bird's eye chilies (crushed or whole).
# *   **Vegetables:** Straw mushrooms or oyster mushrooms, cherry tomatoes.
# *   **Seasoning:** Fish sauce, fresh lime juice, sugar, Thai chili paste (Nam Prik Pao - for a creamy version, optional).
# *   **Garnish:** Fresh cilantro leaves.
#
# ---
#
# ### 3. Japanese Shoyu Ramen (Soy Sauce Ramen)
#
# **Yummy Description:** Slurp your way to happiness with a classic Shoyu Ramen! This beloved Japanese noodle soup features a rich, savory broth primarily flavored with soy sauce, often a blend of chicken and dashi (kelp and dried bonito flakes). The bouncy, springy ramen noodles are nestled in this umami-packed broth, adorned with an array of delectable toppings. Think tender slices of chashu (braised pork belly), a perfectly jammy soft-boiled egg (ajitsuke tamago), crisp bamboo shoots, and a sprinkle of vibrant green scallions – pure comfort in a bowl!
#
# **Key Ingredients:**
#
# *   **Broth (Dashi/Chintan):** Chicken stock, kombu (dried kelp), katsuobushi (dried bonito flakes), pork bones (optional for richer broth).
# *   **Tare (Flavoring Concentrate):** Soy sauce, mirin, sake (optional).
# *   **Noodles:** Fresh or dried ramen noodles.
# *   **Protein:** Chashu (braised pork belly slices), or grilled chicken.
# *   **Toppings:** Ajitsuke Tamago (marinated soft-boiled egg), menma (bamboo shoots), nori (seaweed sheets), chopped scallions, narutomaki (fish cake - optional), sesame oil.
#
# ---
#
# ### 4. Malaysian/Singaporean Laksa (Curry Laksa)
#
# **Yummy Description:** Dive into the luxurious, creamy depths of Laksa, a true culinary gem of Southeast Asia! This captivating noodle soup boasts a rich, spicy, and aromatic coconut curry broth that's utterly irresistible. A complex paste of chilies, galangal, turmeric, and lemongrass forms the heart of its flavor, simmered with coconut milk to velvety perfection. It's brimming with an exciting mix of textures and tastes, often featuring tender chicken, succulent shrimp, crispy fried tofu puffs, and fish cakes, all tangled with thick rice vermicelli and/or yellow egg noodles. A truly satisfying and exotic experience!
#
# **Key Ingredients:**
#
# *   **Broth Base:** Chicken or seafood broth, coconut milk.
# *   **Laksa Paste:** Shallots, garlic, galangal, lemongrass, dried red chilies, turmeric, candlenuts (or macadamia nuts), belacan (shrimp paste - optional but authentic), coriander powder, cumin powder.
# *   **Protein:** Shredded cooked chicken, shrimp, fish cakes, fried tofu puffs (tau pok).
# *   **Noodles:** Thick rice vermicelli and/or yellow egg noodles.
# *   **Garnishes:** Bean sprouts, fresh cilantro, lime wedges, sambal (chili paste) for extra heat.
#
# ---

# %%
response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients
    give me fields of
    recipe_name: str
    description: str
    ingredients: list[str]
    
    not in markdown format
    """
)

response.text
# Out:
# "recipe_name: Tom Yum Goong\ndescription: A vibrant and aromatic Thai hot and sour soup, bursting with the fresh flavors of lemongrass, galangal, kaffir lime leaves, and a fiery chili kick. Succulent shrimp swim in a fragrant broth, making it an invigorating and utterly delicious culinary adventure that will tantalize your taste buds!\ningredients:\n- 1 lb large shrimp, peeled and deveined\n- 4 cups chicken or shrimp broth\n- 2 stalks lemongrass, bruised and cut into 2-inch pieces\n- 1 knob galangal, thinly sliced\n- 5-6 kaffir lime leaves, torn\n- 1-2 Thai bird's eye chilies, bruised or sliced (adjust to taste)\n- 1/4 cup lime juice\n- 2 tablespoons fish sauce\n- 1 cup straw mushrooms or button mushrooms, halved\n- 1/2 cup cherry tomatoes, halved\n- Fresh cilantro for garnish\n\nrecipe_name: Pho Bo (Vietnamese Beef Noodle Soup)\ndescription: A soul-soothing Vietnamese noodle soup, featuring a deeply aromatic and crystal-clear beef broth simmered for hours with star anise, cinnamon, and ginger. Silky rice noodles, tender slices of rare beef, and a generous scattering of fresh herbs create a harmonious symphony of flavors and textures that will transport you to the bustling streets of Vietnam. Absolutely comforting and addictive!\ningredients:\n- 2-3 lbs beef bones (knuckles, marrow bones)\n- 1 lb beef oxtail or chuck roast\n- 1 large onion, halved and charred\n- 4-inch ginger piece, sliced and charred\n- 5-6 star anise pods\n- 2-3 cinnamon sticks\n- 1 tablespoon coriander seeds\n- 1 tablespoon fennel seeds\n- 1/4 cup fish sauce\n- 2 tablespoons rock sugar (or granulated sugar)\n- 1 lb fresh flat rice noodles\n- Thinly sliced raw beef (eye of round or sirloin)\n- Garnishes: bean sprouts, fresh basil, mint, cilantro, lime wedges, sliced jalapeños, hoisin sauce, Sriracha\n\nrecipe_name: Shoyu Ramen (Japanese Soy Sauce Ramen)\ndescription: A classic and incredibly comforting Japanese ramen, featuring springy ramen noodles swimming in a rich, savory chicken or pork broth seasoned with a distinctive soy sauce base (shoyu tare). Topped with tender chashu pork belly, a perfectly soft-boiled ajitama egg, crisp nori, and fresh scallions, each spoonful is a delightful explosion of umami that will warm you from the inside out. Pure bliss in a bowl!\ningredients:\n- 6 cups chicken or pork broth (or a mix)\n- 1/4 cup soy sauce (for shoyu tare)\n- 1 tablespoon mirin (for shoyu tare)\n- 1 teaspoon sesame oil (for shoyu tare, optional)\n- 1 lb fresh or dried ramen noodles\n- 1 lb pork belly, rolled and tied (for chashu)\n- 4 large eggs (for ajitama)\n- Nori sheets, cut into strips\n- Scallions, thinly sliced\n- Narutomaki (fish cake), sliced (optional)\n- Bamboo shoots (menma), optional"

# %%
print(response.text)
# Out:
# recipe_name: Tom Yum Goong
# description: A vibrant and aromatic Thai hot and sour soup, bursting with the fresh flavors of lemongrass, galangal, kaffir lime leaves, and a fiery chili kick. Succulent shrimp swim in a fragrant broth, making it an invigorating and utterly delicious culinary adventure that will tantalize your taste buds!
# ingredients:
# - 1 lb large shrimp, peeled and deveined
# - 4 cups chicken or shrimp broth
# - 2 stalks lemongrass, bruised and cut into 2-inch pieces
# - 1 knob galangal, thinly sliced
# - 5-6 kaffir lime leaves, torn
# - 1-2 Thai bird's eye chilies, bruised or sliced (adjust to taste)
# - 1/4 cup lime juice
# - 2 tablespoons fish sauce
# - 1 cup straw mushrooms or button mushrooms, halved
# - 1/2 cup cherry tomatoes, halved
# - Fresh cilantro for garnish
#
# recipe_name: Pho Bo (Vietnamese Beef Noodle Soup)
# description: A soul-soothing Vietnamese noodle soup, featuring a deeply aromatic and crystal-clear beef broth simmered for hours with star anise, cinnamon, and ginger. Silky rice noodles, tender slices of rare beef, and a generous scattering of fresh herbs create a harmonious symphony of flavors and textures that will transport you to the bustling streets of Vietnam. Absolutely comforting and addictive!
# ingredients:
# - 2-3 lbs beef bones (knuckles, marrow bones)
# - 1 lb beef oxtail or chuck roast
# - 1 large onion, halved and charred
# - 4-inch ginger piece, sliced and charred
# - 5-6 star anise pods
# - 2-3 cinnamon sticks
# - 1 tablespoon coriander seeds
# - 1 tablespoon fennel seeds
# - 1/4 cup fish sauce
# - 2 tablespoons rock sugar (or granulated sugar)
# - 1 lb fresh flat rice noodles
# - Thinly sliced raw beef (eye of round or sirloin)
# - Garnishes: bean sprouts, fresh basil, mint, cilantro, lime wedges, sliced jalapeños, hoisin sauce, Sriracha
#
# recipe_name: Shoyu Ramen (Japanese Soy Sauce Ramen)
# description: A classic and incredibly comforting Japanese ramen, featuring springy ramen noodles swimming in a rich, savory chicken or pork broth seasoned with a distinctive soy sauce base (shoyu tare). Topped with tender chashu pork belly, a perfectly soft-boiled ajitama egg, crisp nori, and fresh scallions, each spoonful is a delightful explosion of umami that will warm you from the inside out. Pure bliss in a bowl!
# ingredients:
# - 6 cups chicken or pork broth (or a mix)
# - 1/4 cup soy sauce (for shoyu tare)
# - 1 tablespoon mirin (for shoyu tare)
# - 1 teaspoon sesame oil (for shoyu tare, optional)
# - 1 lb fresh or dried ramen noodles
# - 1 lb pork belly, rolled and tied (for chashu)
# - 4 large eggs (for ajitama)
# - Nori sheets, cut into strips
# - Scallions, thinly sliced
# - Narutomaki (fish cake), sliced (optional)
# - Bamboo shoots (menma), optional

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingridients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config={"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [
#   {
#     "recipe_name": "Miso Soup",
#     "description": "A traditional Japanese soup consisting of a dashi stock into which softened miso paste is mixed. Various optional ingredients can be added, such as tofu, seaweed, and green onions, making it a comforting and savory starter.",
#     "ingridients": ["Dashi stock", "Miso paste", "Silken tofu", "Wakame seaweed", "Green onions"]
#   },
#   {
#     "recipe_name": "Tom Yum Goong",
#     "description": "A hot and sour Thai soup, famous for its vibrant flavors and aromatic herbs. This iconic soup typically features shrimp, mushrooms, and a spicy broth infused with lemongrass, galangal, kaffir lime leaves, and chili.",
#     "ingridients": ["Shrimp", "Mushrooms", "Lemongrass", "Galangal", "Kaffir lime leaves", "Fish sauce", "Lime juice", "Chili paste", "Cilantro"]
#   },
#   {
#     "recipe_name": "Vietnamese Pho Bo (Beef Noodle Soup)",
#     "description": "Vietnam's national dish, a deeply aromatic and savory beef noodle soup. It features a clear, complex broth simmered for hours with spices like star anise and cinnamon, served with flat rice noodles, tender slices of beef, and fresh herbs.",
#     "ingridients": ["Beef bones", "Beef flank/brisket", "Rice noodles", "Onion", "Ginger", "Star anise", "Cinnamon sticks", "Cardamom pods", "Fish sauce", "Bean sprouts", "Basil", "Lime", "Jalapeños"]
#   },
#   {
#     "recipe_name": "Shoyu Ramen",
#     "description": "A classic Japanese ramen with a clear, brown broth made from chicken or vegetable stock and seasoned with soy sauce (shoyu). It's typically topped with chashu pork, a soft-boiled egg, nori, and green onions, offering a rich and umami-packed experience.",
#     "ingridients": ["Ramen noodles", "Chicken or vegetable broth", "Soy sauce", "Chashu pork", "Soft-boiled egg", "Nori seaweed", "Green onions"]
#   }
# ]

# %%
recipes = response.parsed
len(recipes)
# Out:
# 4

# %%
recipes[0].description
# Out:
# 'A traditional Japanese soup consisting of a dashi stock into which softened miso paste is mixed. Various optional ingredients can be added, such as tofu, seaweed, and green onions, making it a comforting and savory starter.'

# %%
recipes[0].recipe_name
# Out:
# 'Miso Soup'

# %%
recipes[0].ingridients
# Out:
# ['Dashi stock', 'Miso paste', 'Silken tofu', 'Wakame seaweed', 'Green onions']

# %% [markdown]
# ### simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    monthly_fee: int
    living_area: float
    number_romms: int
    type: Literal["apartment", "house"]
    address: str
    
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents= """
    List 50 apartments and houses in Sweden with thaie monthly fee, price,
    living area, number of rooms, address, type if it is apartment or house. All currencies are in SEK. 
    Data should be simulattion of swedish housing.
    """,
    config={"response_mime_type": "application/json", "response_schema": list[Home]}
    )
# Out:
# [{"price": 5490000, "monthly_fee": 4900, "living_area": 93.5, "number_romms": 4, "type": "apartment", "address": "Kungsgatan 18, 111 20 Stockholm"}, {"price": 2860000, "monthly_fee": 2900, "living_area": 58.7, "number_romms": 2, "type": "apartment", "address": "Vasagatan 7B, 411 20 Göteborg"}, {"price": 7250000, "monthly_fee": 2100, "living_area": 149.3, "number_romms": 6, "type": "house", "address": "Granvägen 3, 211 40 Malmö"}, {"price": 2970000, "monthly_fee": 3100, "living_area": 73.1, "number_romms": 3, "type": "apartment", "address": "Storgatan 22, 753 20 Uppsala"}, {"price": 4200000, "monthly_fee": 1600, "living_area": 115.0, "number_romms": 5, "type": "house", "address": "Björkgatan 9, 722 10 Västerås"}, {"price": 2480000, "monthly_fee": 2600, "living_area": 52.4, "number_romms": 2, "type": "apartment", "address": "Drottninggatan 15, 703 60 Örebro"}, {"price": 5100000, "monthly_fee": 1800, "living_area": 138.7, "number_romms": 6, "type": "house", "address": "Ekgatan 12, 582 30 Linköping"}, {"price": 3720000, "monthly_fee": 4100, "living_area": 80.5, "number_romms": 3, "type": "apartment", "address": "Parkvägen 5, 252 20 Helsingborg"}, {"price": 1950000, "monthly_fee": 2500, "living_area": 43.1, "number_romms": 1, "type": "apartment", "address": "Kyrkogatan 3, 553 20 Jönköping"}, {"price": 5880000, "monthly_fee": 1900, "living_area": 160.8, "number_romms": 7, "type": "house", "address": "Storgatan 2, 602 30 Norrköping"}, {"price": 2100000, "monthly_fee": 2300, "living_area": 45.9, "number_romms": 2, "type": "apartment", "address": "Torggatan 11, 903 20 Umeå"}, {"price": 3100000, "monthly_fee": 3500, "living_area": 70.2, "number_romms": 3, "type": "apartment", "address": "Långgatan 8, 222 20 Lund"}, {"price": 6300000, "monthly_fee": 1900, "living_area": 185.2, "number_romms": 8, "type": "house", "address": "Bruksgatan 7, 803 10 Gävle"}, {"price": 2240000, "monthly_fee": 2800, "living_area": 62.0, "number_romms": 2, "type": "apartment", "address": "Vasagatan 22, 503 30 Borås"}, {"price": 4650000, "monthly_fee": 1700, "living_area": 125.6, "number_romms": 5, "type": "house", "address": "Sjögatan 4, 632 20 Eskilstuna"}, {"price": 3800000, "monthly_fee": 4200, "living_area": 85.3, "number_romms": 4, "type": "apartment", "address": "Industrigatan 14, 151 50 Södertälje"}, {"price": 5300000, "monthly_fee": 1800, "living_area": 150.7, "number_romms": 6, "type": "house", "address": "Kaptensgatan 10, 302 40 Halmstad"}, {"price": 2650000, "monthly_fee": 3000, "living_area": 68.8, "number_romms": 3, "type": "apartment", "address": "Storgatan 9, 352 30 Växjö"}, {"price": 7900000, "monthly_fee": 5800, "living_area": 120.1, "number_romms": 5, "type": "apartment", "address": "Birger Jarlsgatan 33, 111 30 Stockholm"}, {"price": 3950000, "monthly_fee": 1500, "living_area": 105.5, "number_romms": 4, "type": "house", "address": "Vasagatan 6, 411 20 Göteborg"}, {"price": 2990000, "monthly_fee": 3400, "living_area": 65.3, "number_romms": 2, "type": "apartment", "address": "Södra vägen 19, 211 40 Malmö"}, {"price": 4800000, "monthly_fee": 1700, "living_area": 130.4, "number_romms": 5, "type": "house", "address": "Norra vägen 11, 753 20 Uppsala"}, {"price": 2100000, "monthly_fee": 2600, "living_area": 48.0, "number_romms": 2, "type": "apartment", "address": "Östra vägen 7, 722 10 Västerås"}, {"price": 6800000, "monthly_fee": 2000, "living_area": 205.1, "number_romms": 8, "type": "house", "address": "Västra vägen 16, 703 60 Örebro"}, {"price": 3500000, "monthly_fee": 3800, "living_area": 78.9, "number_romms": 3, "type": "apartment", "address": "Tegnérgatan 20, 582 30 Linköping"}, {"price": 5990000, "monthly_fee": 1900, "living_area": 175.0, "number_romms": 7, "type": "house", "address": "Karlavägen 8, 252 20 Helsingborg"}, {"price": 2700000, "monthly_fee": 3100, "living_area": 60.5, "number_romms": 2, "type": "apartment", "address": "Fiskargatan 13, 553 20 Jönköping"}, {"price": 8800000, "monthly_fee": 2200, "living_area": 245.9, "number_romms": ...

# %%
homes = response.parsed
len(homes)
# Out:
# 50

# %%
homes[0]
# Out:
# Home(price=5490000, monthly_fee=4900, living_area=93.5, number_romms=4, type='apartment', address='Kungsgatan 18, 111 20 Stockholm')

# %%
homes[0].price, homes[0].address
# Out:
# (5490000, 'Kungsgatan 18, 111 20 Stockholm')

# %%
homes[0].__dict__
# Out:
# {'price': 5490000,
#  'monthly_fee': 4900,
#  'living_area': 93.5,
#  'number_romms': 4,
#  'type': 'apartment',
#  'address': 'Kungsgatan 18, 111 20 Stockholm'}

# %%
response.text
# Out:
# '[{"price": 5490000, "monthly_fee": 4900, "living_area": 93.5, "number_romms": 4, "type": "apartment", "address": "Kungsgatan 18, 111 20 Stockholm"}, {"price": 2860000, "monthly_fee": 2900, "living_area": 58.7, "number_romms": 2, "type": "apartment", "address": "Vasagatan 7B, 411 20 Göteborg"}, {"price": 7250000, "monthly_fee": 2100, "living_area": 149.3, "number_romms": 6, "type": "house", "address": "Granvägen 3, 211 40 Malmö"}, {"price": 2970000, "monthly_fee": 3100, "living_area": 73.1, "number_romms": 3, "type": "apartment", "address": "Storgatan 22, 753 20 Uppsala"}, {"price": 4200000, "monthly_fee": 1600, "living_area": 115.0, "number_romms": 5, "type": "house", "address": "Björkgatan 9, 722 10 Västerås"}, {"price": 2480000, "monthly_fee": 2600, "living_area": 52.4, "number_romms": 2, "type": "apartment", "address": "Drottninggatan 15, 703 60 Örebro"}, {"price": 5100000, "monthly_fee": 1800, "living_area": 138.7, "number_romms": 6, "type": "house", "address": "Ekgatan 12, 582 30 Linköping"}, {"price": 3720000, "monthly_fee": 4100, "living_area": 80.5, "number_romms": 3, "type": "apartment", "address": "Parkvägen 5, 252 20 Helsingborg"}, {"price": 1950000, "monthly_fee": 2500, "living_area": 43.1, "number_romms": 1, "type": "apartment", "address": "Kyrkogatan 3, 553 20 Jönköping"}, {"price": 5880000, "monthly_fee": 1900, "living_area": 160.8, "number_romms": 7, "type": "house", "address": "Storgatan 2, 602 30 Norrköping"}, {"price": 2100000, "monthly_fee": 2300, "living_area": 45.9, "number_romms": 2, "type": "apartment", "address": "Torggatan 11, 903 20 Umeå"}, {"price": 3100000, "monthly_fee": 3500, "living_area": 70.2, "number_romms": 3, "type": "apartment", "address": "Långgatan 8, 222 20 Lund"}, {"price": 6300000, "monthly_fee": 1900, "living_area": 185.2, "number_romms": 8, "type": "house", "address": "Bruksgatan 7, 803 10 Gävle"}, {"price": 2240000, "monthly_fee": 2800, "living_area": 62.0, "number_romms": 2, "type": "apartment", "address": "Vasagatan 22, 503 30 Borås"}, {"price": 4650000, "monthly_fee": 1700, "living_area": 125.6, "number_romms": 5, "type": "house", "address": "Sjögatan 4, 632 20 Eskilstuna"}, {"price": 3800000, "monthly_fee": 4200, "living_area": 85.3, "number_romms": 4, "type": "apartment", "address": "Industrigatan 14, 151 50 Södertälje"}, {"price": 5300000, "monthly_fee": 1800, "living_area": 150.7, "number_romms": 6, "type": "house", "address": "Kaptensgatan 10, 302 40 Halmstad"}, {"price": 2650000, "monthly_fee": 3000, "living_area": 68.8, "number_romms": 3, "type": "apartment", "address": "Storgatan 9, 352 30 Växjö"}, {"price": 7900000, "monthly_fee": 5800, "living_area": 120.1, "number_romms": 5, "type": "apartment", "address": "Birger Jarlsgatan 33, 111 30 Stockholm"}, {"price": 3950000, "monthly_fee": 1500, "living_area": 105.5, "number_romms": 4, "type": "house", "address": "Vasagatan 6, 411 20 Göteborg"}, {"price": 2990000, "monthly_fee": 3400, "living_area": 65.3, "number_romms": 2, "type": "apartment", "address": "Södra vägen 19, 211 40 Malmö"}, {"price": 4800000, "monthly_fee": 1700, "living_area": 130.4, "number_romms": 5, "type": "house", "address": "Norra vägen 11, 753 20 Uppsala"}, {"price": 2100000, "monthly_fee": 2600, "living_area": 48.0, "number_romms": 2, "type": "apartment", "address": "Östra vägen 7, 722 10 Västerås"}, {"price": 6800000, "monthly_fee": 2000, "living_area": 205.1, "number_romms": 8, "type": "house", "address": "Västra vägen 16, 703 60 Örebro"}, {"price": 3500000, "monthly_fee": 3800, "living_area": 78.9, "number_romms": 3, "type": "apartment", "address": "Tegnérgatan 20, 582 30 Linköping"}, {"price": 5990000, "monthly_fee": 1900, "living_area": 175.0, "number_romms": 7, "type": "house", "address": "Karlavägen 8, 252 20 Helsingborg"}, {"price": 2700000, "monthly_fee": 3100, "living_area": 60.5, "number_romms": 2, "type": "apartment", "address": "Fiskargatan 13, 553 20 Jönköping"}, {"price": 8800000, "monthly_fee": 2200, "living_area": 245.9, "number_romms" ...

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])
df.head()
# Out:
#      price  monthly_fee  living_area  number_romms       type  \
# 0  5490000         4900         93.5             4  apartment
# 1  2860000         2900         58.7             2  apartment
# 2  7250000         2100        149.3             6      house
# 3  2970000         3100         73.1             3  apartment
# 4  4200000         1600        115.0             5      house
#
#                            address
# 0  Kungsgatan 18, 111 20 Stockholm
# 1    Vasagatan 7B, 411 20 Göteborg
# 2        Granvägen 3, 211 40 Malmö
# 3     Storgatan 22, 753 20 Uppsala
# 4    Björkgatan 9, 722 10 Västerås

# %%
cheap_houses = df.query("price < 5_000_000 and type == 'house'")
cheap_houses
# Out:
#       price  monthly_fee  living_area  number_romms   type  \
# 4   4200000         1600        115.0             5  house
# 14  4650000         1700        125.6             5  house
# 19  3950000         1500        105.5             4  house
# 21  4800000         1700        130.4             5  house
# 37  4500000         1600        120.3             5  house
#
#                            address
# 4    Björkgatan 9, 722 10 Västerås
# 14   Sjögatan 4, 632 20 Eskilstuna
# 19    Vasagatan 6, 411 20 Göteborg
# 21  Norra vägen 11, 753 20 Uppsala
# 37   Vasagatan 15, 411 20 Göteborg

# %%
cheap_houses.to_csv("cheap_houses.csv", index=False)
